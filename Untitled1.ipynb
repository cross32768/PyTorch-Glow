# %%
import matplotlib.pyplot as plt

import torch
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader

from torch.distributions.normal import Normal
from torch.distributions.multivariate_normal import MultivariateNormal

# %%
n_sample = 10000
z = MultivariateNormal(torch.zeros(2), torch.eye(2))
sampled_z = z.sample((n_sample,))
plt.figure(figsize = (5,5))
plt.xlim([-4, 4])
plt.ylim([-4, 4])
plt.scatter(sampled_z[:,0], sampled_z[:,1], s=15)

# %%
def doublemoon_sample(n_sample):
    x1_1 = Normal(4, 4)
    sampled_x1_1 = x1_1.sample((int(n_sample/2),))
    x2_1 = Normal(0.25*(sampled_x1_1-4)**2-20, torch.ones_like(sampled_x1_1)*2)
    sampled_x2_1 = x2_1.sample()

    x1_2 = Normal(-4, 4)
    sampled_x1_2 = x1_2.sample((int(n_sample/2),))
    x2_2 = Normal(-0.25*(sampled_x1_2+4)**2+20, torch.ones_like(sampled_x1_2)*2)
    sampled_x2_2 = x2_2.sample()

    sampled_x1 = torch.cat([sampled_x1_1, sampled_x1_2])
    sampled_x2 = torch.cat([sampled_x2_1, sampled_x2_2])
    sampled_x = torch.zeros(n_sample, 2)
    sampled_x[:,0] = sampled_x1*0.2
    sampled_x[:,1] = sampled_x2*0.1
    
    return sampled_x

# %%
sampled_x = doublemoon_sample(n_sample)
plt.figure(figsize = (5,5))
plt.xlim([-4, 4])
plt.ylim([-4, 4])
plt.scatter(sampled_x[:,0],sampled_x[:,1], s=15)

# %%
train_loader = DataLoader(sampled_x, batch_size=64, shuffle=True)

# %%
class NN(nn.Module):
    def __init__(self, n_input, n_hidden):
        super(NN, self).__init__()
        self.fc1 = nn.Linear(n_input, n_hidden)
        self.fc2 = nn.Linear(n_hidden, n_hidden)
        self.fc3_log_s = nn.Linear(n_hidden, n_input)
        self.fc3_bias = nn.Linear(n_hidden, n_input)
        
    def forward(self, x):
        hidden = F.relu(self.fc2(F.relu(self.fc1(x))))
        log_s = torch.tanh(self.fc3_log_s(hidden))
        bias = self.fc3_bias(hidden)
        return log_s, bias

# %%
class RealNVP(nn.Module):
    def __init__(self, n_flows, data_dim, n_hidden):
        super(RealNVP, self).__init__()
        self.n_flows = n_flows
        self.NN = torch.nn.ModuleList()
        
        assert(data_dim % 2 == 0)
        self.n_half = int(data_dim/2)
        
        for k in range(n_flows):
            self.NN.append(NN(self.n_half, n_hidden))
        
    def forward(self, x, n_layers=None):
        if not n_layers:
            n_layers = self.n_flows
            
        log_det_jacobian = 0
        for k in range(n_layers):
            x_a = x[:, :self.n_half]
            x_b = x[:, self.n_half:]
            
            log_s, bias = self.NN[k](x_a)
            x_b = torch.exp(log_s)*x_b + bias
            
            x = torch.cat([x_b, x_a], dim=1)
            
            log_det_jacobian += log_s
        
        return x, log_det_jacobian
        
        
    def inverse(self, z, n_layers=None):
        if not n_layers:
            n_layers = self.n_flows
            
        for k in reversed(range(n_layers)):
            z_a = z[:, self.n_half:]
            z_b = z[:, :self.n_half]
            
            log_s, bias = self.NN[k](z_a)
            z_b = (z_b - bias) / torch.exp(log_s)
            
            z = torch.cat([z_a, z_b], dim=1)
        
        return z

# %%
net = RealNVP(4, 2, 256)
learning_rate = 0.0001
optimizer = optim.Adam(net.parameters(), lr=learning_rate)

# %%
n_epochs = 50
for epoch in range(n_epochs):
    running_loss = 0
    for sample_x in train_loader:
        optimizer.zero_grad()
        sample_x = sample_x
        sample_z, log_det_jacobian = net(sample_x)
        loss = -1 * torch.mean(z.log_prob(sample_z.cpu()) + log_det_jacobian)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    print('epoch:[%2d/%2d] loss:%1.4f' % (epoch+1, n_epochs, running_loss / len(train_loader)))
# Out:
# epoch:[ 1/50] loss:2.8737
# epoch:[ 2/50] loss:2.2213
# epoch:[ 3/50] loss:2.0075
# epoch:[ 4/50] loss:1.9307
# epoch:[ 5/50] loss:1.8942
# epoch:[ 6/50] loss:1.8745
# epoch:[ 7/50] loss:1.8422
# epoch:[ 8/50] loss:1.8366
# epoch:[ 9/50] loss:1.8209
# epoch:[10/50] loss:1.8317
# epoch:[11/50] loss:1.8177
# epoch:[12/50] loss:1.8172
# epoch:[13/50] loss:1.8058
# epoch:[14/50] loss:1.8061
# epoch:[15/50] loss:1.7931
# epoch:[16/50] loss:1.7938
# epoch:[17/50] loss:1.8028
# epoch:[18/50] loss:1.8091
# epoch:[19/50] loss:1.7932
# epoch:[20/50] loss:1.7969
# epoch:[21/50] loss:1.7875
# epoch:[22/50] loss:1.7928
# epoch:[23/50] loss:1.7965
# epoch:[24/50] loss:1.7968
# epoch:[25/50] loss:1.7956
# epoch:[26/50] loss:1.7846
# epoch:[27/50] loss:1.7829
# epoch:[28/50] loss:1.7821
# epoch:[29/50] loss:1.7810
# epoch:[30/50] loss:1.7848
# epoch:[31/50] loss:1.7858
# epoch:[32/50] loss:1.7816
# epoch:[33/50] loss:1.7871
# epoch:[34/50] loss:1.7771
# epoch:[35/50] loss:1.7846
# epoch:[36/50] loss:1.7881
# epoch:[37/50] loss:1.7801
# epoch:[38/50] loss:1.7854
# epoch:[39/50] loss:1.7755
# epoch:[40/50] loss:1.7799
# epoch:[41/50] loss:1.7998
# epoch:[42/50] loss:1.7709
# epoch:[43/50] loss:1.7661
# epoch:[44/50] loss:1.7822
# epoch:[45/50] loss:1.7685
# epoch:[46/50] loss:1.7785
# epoch:[47/50] loss:1.7749
# epoch:[48/50] loss:1.7782
# epoch:[49/50] loss:1.7730
# epoch:[50/50] loss:1.7726

# %%
with torch.no_grad():
    new_sampled_z = z.sample((5000,))
    predicted_x = net.inverse(new_sampled_z)
plt.figure(figsize = (5,5))
plt.xlim([-4, 4])
plt.ylim([-4, 4])
plt.scatter(predicted_x[:,0], predicted_x[:,1], s=15)

# %%
with torch.no_grad():
    new_sampled_x = doublemoon_sample(5000)
    predicted_z, _ = net(new_sampled_x)
plt.figure(figsize = (5,5))
plt.xlim([-4, 4])
plt.ylim([-4, 4])
plt.scatter(predicted_z[:,0], predicted_z[:,1], s=15)

# %%
with torch.no_grad():
    new_sampled_z = z.sample((5000,))
    predicted_x = net.inverse(new_sampled_z, 4)
plt.figure(figsize = (5,5))
plt.xlim([-4, 4])
plt.ylim([-4, 4])
plt.scatter(predicted_x[:,0], predicted_x[:,1], s=15)

# %%
with torch.no_grad():
    new_sampled_z = z.sample((5000,))
    predicted_x = net.inverse(new_sampled_z, 3)
plt.figure(figsize = (5,5))
plt.xlim([-4, 4])
plt.ylim([-4, 4])
plt.scatter(predicted_x[:,0], predicted_x[:,1], s=15)

# %%
with torch.no_grad():
    new_sampled_z = z.sample((5000,))
    predicted_x = net.inverse(new_sampled_z, 2)
plt.figure(figsize = (5,5))
plt.xlim([-4, 4])
plt.ylim([-4, 4])
plt.scatter(predicted_x[:,0], predicted_x[:,1], s=15)

# %%
with torch.no_grad():
    new_sampled_z = z.sample((5000,))
    predicted_x = net.inverse(new_sampled_z, 1)
plt.figure(figsize = (5,5))
plt.xlim([-4, 4])
plt.ylim([-4, 4])
plt.scatter(predicted_x[:,0], predicted_x[:,1], s=15)

# %%
with torch.no_grad():
    new_sampled_x = doublemoon_sample(5000)
    predicted_z, _ = net(new_sampled_x, 1)
plt.figure(figsize = (5,5))
plt.xlim([-4, 4])
plt.ylim([-4, 4])
plt.scatter(predicted_z[:,0], predicted_z[:,1], s=15)

# %%
with torch.no_grad():
    new_sampled_x = doublemoon_sample(5000)
    predicted_z, _ = net(new_sampled_x, 2)
plt.figure(figsize = (5,5))
plt.xlim([-4, 4])
plt.ylim([-4, 4])
plt.scatter(predicted_z[:,0], predicted_z[:,1], s=15)

# %%
with torch.no_grad():
    new_sampled_x = doublemoon_sample(5000)
    predicted_z, _ = net(new_sampled_x, 3)
plt.figure(figsize = (5,5))
plt.xlim([-4, 4])
plt.ylim([-4, 4])
plt.scatter(predicted_z[:,0], predicted_z[:,1], s=15)

# %%
with torch.no_grad():
    new_sampled_x = doublemoon_sample(5000)
    predicted_z, _ = net(new_sampled_x, 4)
plt.figure(figsize = (5,5))
plt.xlim([-4, 4])
plt.ylim([-4, 4])
plt.scatter(predicted_z[:,0], predicted_z[:,1], s=15)
